# %% [markdown]
# # Schedule Games x Weeks

# %% [markdown]
# # Description
#
# ### Data
#
# Games Calender for each week
#
# ### ETL
#
# Content extracted from the site: https://www.nba.com/schedule?cal=all&pd=false
#
# The html content was extracted manually and parsed in this notebook.
# The result is a json file.
#
# ### To Dos
# - chart with top teams
# - extract teams player data
# - readable list-table of games

# %% [markdown]
# # Walk, don´t run

# %%
import os
import sys
import pandas as pd
from lxml import html
from lxml import etree
import json

# %%
_notebookFolder = 'nb-001'
_version = '1.0'

# %% [markdown]
# ### Load data

# %%
# html content from https://www.nba.com/schedule?cal=all&pd=false
with open('../../data/universe/scrap-schedule/body.html', 'r', encoding='utf-8') as f:
    htmlContent= f.read()

# %%
tree = html.fromstring(htmlContent)

# %%
# Weeks
contentDiv = tree.getchildren()
weekEs = contentDiv[2].getchildren()
len(weekEs)
# Out:
# 12

# %% [markdown]
# ---

# %% [markdown]
# ### Utils

# %%
def extract_weekData( _weekE ):
    weekDaysEs = []
    weekDateT = ''
    weekDateE = _weekE.cssselect('h2')
    # case: contains headline text element
    if(len(weekDateE)):
        weekDateT = _weekE.cssselect('h2')[0].text_content()
        # print('DATA:','weekDateT:', weekDateT)
        weekDaysEs = _weekE.getchildren()[1:]
    else:
        # print('LOG:',' no week text')
        weekDaysEs = _weekE.getchildren()
    return {
        'Es': weekDaysEs,
        'week_date': weekDateT
    }

# %%
# Infos week day 
def extract_weekDayData( _weekDaysE ):
    weekDaysInfosE = _weekDaysE.getchildren()[0]

    weekDaysInfoCalenderT = weekDaysInfosE.cssselect('h4')[0].text_content()
    weekDaysInfoWeekGamesT = weekDaysInfosE.cssselect('h6')[0].text_content()

    weekDaysContentEs = _weekDaysE.getchildren()[1].getchildren()[1:] #ignore hiddens
    return {
        'calenderT': weekDaysInfoCalenderT,
        'infoGamesT': weekDaysInfoWeekGamesT,
        'contentEs': weekDaysContentEs,
    }

# %%
# from each weekDaysContentEs

def extract_gameTeamsData( _weekDaysContentE ):
    gamesEs = _weekDaysContentE.getchildren()
    gameData = []
    for gameE in gamesEs:
        contentLinksEs = gameE.cssselect('a.text-cerulean')
        teamLinks = [link for link in contentLinksEs if '/team/' in  link.get('href')]
        gameItems = []
        for idx, tl in enumerate(teamLinks):
            # print('-', tl.text_content(), tl.get('href'))
            gameItems.append({
                'team_name': tl.text_content(),
                'team_link_abs': 'https://www.nba.com' + tl.get('href'),
            })
        # print('\r')
        gameData.append(gameItems)
    return gameData

# %% [markdown]
# ---

# %% [markdown]
# ### Main

# %%
## Usage summary example
D = extract_weekData( weekEs[1] ) # Week 2
dE = D['Es'][0] # Day 1
E = extract_weekDayData( dE )
eE = E['contentEs'][0] # Game 1
F = extract_gameTeamsData( eE )
F[0]
# Out:
# [{'team_name': 'Golden State Warriors',
#   'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#  {'team_name': 'Brooklyn Nets',
#   'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}]

# %%
mainData = []

for weekE in weekEs:
    
    D = extract_weekData( weekE )
    
    gamesData= []
    
    for dE in D['Es']:
        
        E = extract_weekDayData( dE ) 
        
        gameTeamsData = []
        
        for eE in E['contentEs']:
            gameTeamsData = extract_gameTeamsData( eE ) 
        
        gameItem = {
            'day_date': E['calenderT'],
            'day_games': E['infoGamesT'],
            'day_teams': gameTeamsData
        }
        gamesData.append(gameItem)
    
    mainDataItem = {
        'week_date': D['week_date'],
        'week_games': gamesData
    }
    mainData.append(mainDataItem)

mainData
# Out:
# [{'week_date': '',
#   'week_games': [{'day_date': 'Friday, December 11',
#     'day_games': ' 5 Games',
#     'day_teams': [[{'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'},
#       {'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'}],
#      [{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}],
#      [{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}]]},
#    {'day_date': 'Saturday, December 12',
#     'day_games': ' 7 Games',
#     'day_teams': [[{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'}],
#      [{'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'},
#       {'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'}]]},
#    {'day_date': 'Sunday, December 13',
#     'day_games': ' 6 Games',
#     'day_teams': [[{'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'},
#       {'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'}],
#      [{'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}],
#      [{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}]]},
#    {'day_date': 'Monday, December 14',
#     'day_games': ' 6 Games',
#     'day_teams': [[{'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'},
#       {'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'}],
#      [{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'}],
#      [{'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'}]]},
#    {'day_date': 'Tuesday, December 15',
#     'day_games': ' 3 Games',
#     'day_teams': [[{'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}]]},
#    {'day_date': 'Wednesday, December 16',
#     'day_games': ' 4 Games',
#     'day_teams': [[{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'}],
#      [{'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'}]]},
#    {'day_date': 'Thursday, December 17',
#     'day_games': ' 7 Games',
#     'day_teams': [[{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'},
#       {'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'}],
#      [{'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'}]]},
#    {'day_date': 'Friday, December 18',
#     'day_games': ' 8 Games',
#     'day_teams': [[{'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'},
#       {'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'}],
#      [{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'}],
#      [{'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'}]]},
#    {'day_date': 'Saturday, December 19',
#     'day_games': ' 3 Games',
#     'day_teams': [[{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}]]}]},
#  {'week_date': 'Week 1 (Dec 22 - Dec 27)',
#   'week_games': [{'day_date': 'Tuesday, December 22',
#     'day_games': 'Week 1 |  2 Games',
#     'day_teams': [[{'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}]]},
#    {'day_date': 'Wednesday, December 23',
#     'day_games': 'Week 1 |  13 Games',
#     'day_teams': [[{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'}],
#      [{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'},
#       {'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}],
#      [{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'}]]},
#    {'day_date': 'Friday, December 25',
#     'day_games': 'Week 1 |  5 Games',
#     'day_teams': [[{'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}]]},
#    {'day_date': 'Saturday, December 26',
#     'day_games': 'Week 1 |  10 Games',
#     'day_teams': [[{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'}],
#      [{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'},
#       {'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'}],
#      [{'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}]]},
#    {'day_date': 'Sunday, December 27',
#     'day_games': 'Week 1 |  10 Games',
#     'day_teams': [[{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'}],
#      [{'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'},
#       {'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'}],
#      [{'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'},
#       {'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'}],
#      [{'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}],
#      [{'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}]]}]},
#  {'week_date': 'Week 2 (Dec 28 - Jan 03)',
#   'week_games': [{'day_date': 'Monday, December 28',
#     'day_games': 'Week 2 |  5 Games',
#     'day_teams': [[{'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'},
#       {'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'}],
#      [{'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'}],
#      [{'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}],
#      [{'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}]]},
#    {'day_date': 'Tuesday, December 29',
#     'day_games': 'Week 2 |  10 Games',
#     'day_teams': [[{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'}],
#      [{'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'},
#       {'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'}],
#      [{'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'},
#       {'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'}],
#      [{'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'},
#       {'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'}],
#      [{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}]]},
#    {'day_date': 'Wednesday, December 30',
#     'day_games': 'Week 2 |  6 Games',
#     'day_teams': [[{'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'},
#       {'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'}]]},
#    {'day_date': 'Thursday, December 31',
#     'day_games': 'Week 2 |  7 Games',
#     'day_teams': [[{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'}],
#      [{'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'},
#       {'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'}]]},
#    {'day_date': 'Friday, January 01',
#     'day_games': 'Week 2 |  10 Games',
#     'day_teams': [[{'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'},
#       {'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'}],
#      [{'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'},
#       {'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'}],
#      [{'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'},
#       {'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'}]]},
#    {'day_date': 'Saturday, January 02',
#     'day_games': 'Week 2 |  6 Games',
#     'day_teams': [[{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'}],
#      [{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}]]},
#    {'day_date': 'Sunday, January 03',
#     'day_games': 'Week 2 |  8 Games',
#     'day_teams': [[{'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'}],
#      [{'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'},
#       {'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'}]]}]},
#  {'week_date': 'Week 3 (Jan 04 - Jan 10)',
#   'week_games': [{'day_date': 'Monday, January 04',
#     'day_games': 'Week 3 |  9 Games',
#     'day_teams': [[{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'},
#       {'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'}],
#      [{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'}]]},
#    {'day_date': 'Tuesday, January 05',
#     'day_games': 'Week 3 |  5 Games',
#     'day_teams': [[{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}]]},
#    {'day_date': 'Wednesday, January 06',
#     'day_games': 'Week 3 |  11 Games',
#     'day_teams': [[{'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'}],
#      [{'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}]]},
#    {'day_date': 'Thursday, January 07',
#     'day_games': 'Week 3 |  5 Games',
#     'day_teams': [[{'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}],
#      [{'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}]]},
#    {'day_date': 'Friday, January 08',
#     'day_games': 'Week 3 |  10 Games',
#     'day_teams': [[{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}],
#      [{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}]]},
#    {'day_date': 'Saturday, January 09',
#     'day_games': 'Week 3 |  8 Games',
#     'day_teams': [[{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'},
#       {'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'}],
#      [{'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}]]},
#    {'day_date': 'Sunday, January 10',
#     'day_games': 'Week 3 |  8 Games',
#     'day_teams': [[{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'}]]}]},
#  {'week_date': 'Week 4 (Jan 11 - Jan 17)',
#   'week_games': [{'day_date': 'Monday, January 11',
#     'day_games': 'Week 4 |  8 Games',
#     'day_teams': [[{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'}],
#      [{'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'},
#       {'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'}],
#      [{'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
# ...
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'}],
#      [{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'},
#       {'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'}]]},
#    {'day_date': 'Thursday, February 25',
#     'day_games': 'Week 10 |  6 Games',
#     'day_teams': [[{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}],
#      [{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'},
#       {'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'}],
#      [{'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}]]},
#    {'day_date': 'Friday, February 26',
#     'day_games': 'Week 10 |  9 Games',
#     'day_teams': [[{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'},
#       {'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'}],
#      [{'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}]]},
#    {'day_date': 'Saturday, February 27',
#     'day_games': 'Week 10 |  7 Games',
#     'day_teams': [[{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'},
#       {'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'}],
#      [{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'}]]},
#    {'day_date': 'Sunday, February 28',
#     'day_games': 'Week 10 |  9 Games',
#     'day_teams': [[{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'}],
#      [{'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}]]}]},
#  {'week_date': 'Week 11 (Mar 01 - Mar 07)',
#   'week_games': [{'day_date': 'Monday, March 01',
#     'day_games': 'Week 11 |  7 Games',
#     'day_teams': [[{'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'}],
#      [{'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}]]},
#    {'day_date': 'Tuesday, March 02',
#     'day_games': 'Week 11 |  7 Games',
#     'day_teams': [[{'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'}],
#      [{'team_name': 'Detroit Pistons',
#        'team_link_abs': 'https://www.nba.com/team/1610612765/pistons/'},
#       {'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'}],
#      [{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'}],
#      [{'team_name': 'New York Knicks',
#        'team_link_abs': 'https://www.nba.com/team/1610612752/knicks/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Phoenix Suns',
#        'team_link_abs': 'https://www.nba.com/team/1610612756/suns/'},
#       {'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'}]]},
#    {'day_date': 'Wednesday, March 03',
#     'day_games': 'Week 11 |  9 Games',
#     'day_teams': [[{'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'},
#       {'team_name': 'Cleveland Cavaliers',
#        'team_link_abs': 'https://www.nba.com/team/1610612739/cavaliers/'}],
#      [{'team_name': 'Atlanta Hawks',
#        'team_link_abs': 'https://www.nba.com/team/1610612737/hawks/'},
#       {'team_name': 'Orlando Magic',
#        'team_link_abs': 'https://www.nba.com/team/1610612753/magic/'}],
#      [{'team_name': 'Utah Jazz',
#        'team_link_abs': 'https://www.nba.com/team/1610612762/jazz/'},
#       {'team_name': 'Philadelphia 76ers',
#        'team_link_abs': 'https://www.nba.com/team/1610612755/sixers/'}],
#      [{'team_name': 'Brooklyn Nets',
#        'team_link_abs': 'https://www.nba.com/team/1610612751/nets/'},
#       {'team_name': 'Houston Rockets',
#        'team_link_abs': 'https://www.nba.com/team/1610612745/rockets/'}],
#      [{'team_name': 'Charlotte Hornets',
#        'team_link_abs': 'https://www.nba.com/team/1610612766/hornets/'},
#       {'team_name': 'Minnesota Timberwolves',
#        'team_link_abs': 'https://www.nba.com/team/1610612750/timberwolves/'}],
#      [{'team_name': 'Chicago Bulls',
#        'team_link_abs': 'https://www.nba.com/team/1610612741/bulls/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'Dallas Mavericks',
#        'team_link_abs': 'https://www.nba.com/team/1610612742/mavericks/'}],
#      [{'team_name': 'Golden State Warriors',
#        'team_link_abs': 'https://www.nba.com/team/1610612744/warriors/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}],
#      [{'team_name': 'Los Angeles Lakers',
#        'team_link_abs': 'https://www.nba.com/team/1610612747/lakers/'},
#       {'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'}]]},
#    {'day_date': 'Thursday, March 04',
#     'day_games': 'Week 11 |  7 Games',
#     'day_teams': [[{'team_name': 'Toronto Raptors',
#        'team_link_abs': 'https://www.nba.com/team/1610612761/raptors/'},
#       {'team_name': 'Boston Celtics',
#        'team_link_abs': 'https://www.nba.com/team/1610612738/celtics/'}],
#      [{'team_name': 'Denver Nuggets',
#        'team_link_abs': 'https://www.nba.com/team/1610612743/nuggets/'},
#       {'team_name': 'Indiana Pacers',
#        'team_link_abs': 'https://www.nba.com/team/1610612754/pacers/'}],
#      [{'team_name': 'LA Clippers',
#        'team_link_abs': 'https://www.nba.com/team/1610612746/clippers/'},
#       {'team_name': 'Washington Wizards',
#        'team_link_abs': 'https://www.nba.com/team/1610612764/wizards/'}],
#      [{'team_name': 'Milwaukee Bucks',
#        'team_link_abs': 'https://www.nba.com/team/1610612749/bucks/'},
#       {'team_name': 'Memphis Grizzlies',
#        'team_link_abs': 'https://www.nba.com/team/1610612763/grizzlies/'}],
#      [{'team_name': 'Oklahoma City Thunder',
#        'team_link_abs': 'https://www.nba.com/team/1610612760/thunder/'},
#       {'team_name': 'San Antonio Spurs',
#        'team_link_abs': 'https://www.nba.com/team/1610612759/spurs/'}],
#      [{'team_name': 'Miami Heat',
#        'team_link_abs': 'https://www.nba.com/team/1610612748/heat/'},
#       {'team_name': 'New Orleans Pelicans',
#        'team_link_abs': 'https://www.nba.com/team/1610612740/pelicans/'}],
#      [{'team_name': 'Sacramento Kings',
#        'team_link_abs': 'https://www.nba.com/team/1610612758/kings/'},
#       {'team_name': 'Portland Trail Blazers',
#        'team_link_abs': 'https://www.nba.com/team/1610612757/blazers/'}]]}]}]

# %% [markdown]
# ### Save Data

# %%
productPath = '../../data/master/schedule/'

if not os.path.exists( productPath ):
    os.makedirs( productPath )

# %%
productFileName = f'{_notebookFolder}__games-calendar-{_version}.json'

productFullPath = productPath + productFileName

# %%
with open( productFullPath, 'w') as outfile:
    json.dump(mainData, outfile, indent=4)

# %% [markdown]
# # Docs
#
# ### LXML cssselect
#
# - https://lxml.de/xpathxslt.html
# - https://lxml.de/cssselect.html
# - https://cssselect.readthedocs.io/en/latest/
