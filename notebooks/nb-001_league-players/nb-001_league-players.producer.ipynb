# %%
# import sys
# import os
# import urllib, base64
# import datetime as dt
# import numpy as np
import pandas as pd
# import json 
# from pandas.io.json import json_normalize  
# from matplotlib import cm
# import matplotlib.pyplot as plt
# from matplotlib import colors as mcolors
# import base64
# import re
# import base64

import requests
from pandas.io.json import json_normalize

# %%
# %store -r

# %%
# %run ../shared/nb-nba.class.ipynb

# %%
_notebookFolder = 'nb-001'
_version = '1.0'

# %%
nba = Nba()

# %%
seasonsList = ['2019-20']

# %%
targetSeason = seasonsList[ 0 ]

requestParams = {
 'name': 'leagueLeaders',
 'params' :  [ 
    ('LeagueID', '00'),
    ('PerMode', 'Totals'),
    ('Scope', 'S'),
    ('Season', targetSeason),
    ('SeasonType', 'Regular Season'),
    ('StatCategory', 'PTS')
  ]
}

result = requests.get( nba.apiUrl + requestParams['name'], params=requestParams['params'], headers= nba.headers)
resultObj =  result.json()

# %%
headers = resultObj['resultSet']['headers']
data = resultObj['resultSet']['rowSet']
# dfLog = json_normalize( data=data, meta=headers) 

df0 = pd.DataFrame(data,  columns=headers)

# %%
df0
# Out:
#      PLAYER_ID  RANK                   PLAYER TEAM  GP   MIN  FGM   FGA  \
# 0       201935     1             James Harden  HOU  68  2483  672  1514
# 1       203081     2           Damian Lillard  POR  66  2474  624  1349
# 2      1626164     3             Devin Booker  PHX  70  2512  627  1283
# 3       203507     4    Giannis Antetokounmpo  MIL  63  1917  685  1238
# 4      1629027     5               Trae Young  ATL  60  2120  546  1249
# 5      1629029     6              Luka Doncic  DAL  61  2047  581  1255
# 6       203078     7             Bradley Beal  WAS  57  2053  593  1303
# 7         2544     8             LeBron James  LAL  67  2316  643  1303
# 8      1628378     9         Donovan Mitchell  UTA  69  2364  602  1342
# 9       203076    10            Anthony Davis  LAL  62  2131  551  1096
# 10      203468    11              CJ McCollum  POR  70  2557  611  1356
# 11      201566    12        Russell Westbrook  HOU  57  2049  604  1281
# ...

# %%
##  Open data
with open('../../data/master/data.json') as f: 
    dfData = json.load(f)

dfData
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-f6dd8de995b8> in <module>
#       1 ##  Open data
# ----> 2 with open('../../data/master/data.json') as f:
#       3     dfData = json.load(f)
#       4
#       5 dfData
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/master/data.json'

# %% [markdown]
# # Run

# %% [markdown]
# ## Save Data

# %%
dfOutput = dfResult

# %%
productPath = '../../data/master/products/'
productFileName = f'{_notebookFolder}__filename-{_version}.csv'

productFullPath = productPath + productFileName

# %%
dfOutput.to_csv(productFullPath, index=False)
